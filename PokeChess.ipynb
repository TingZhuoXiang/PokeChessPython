# %% [markdown]
# <a href="https://colab.research.google.com/github/TingZhuoXiang/PokeChessPython/blob/main/PokeChess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from random import randint
types = ['normal','fire','water','grass','electric','ice','fighting','poison','ground','flying','psychic','bug','rock','ghost','dragon','dark','steel','fairy']
type_advantages = [[[],['rock','steel'],['ghost']],[['grass','ice','bug','steel'],['fire','water','rock','dragon'],[]],[['fire','ground','rock'],['water','grass','dragon'],[]],[['water','ground','rock'],['fire','grass','poison','flying','bug','dragon','steel'],[]],[['water','flying'],['grass','electric','dragon'],['ground']],[['grass','ground','flying','dragon'],['fire','water','ice','steel'],[]],[['normal','ice','rock','dark','steel'],['poison','flying','psychic','bug','fairy'],['ghost']],[['grass','fairy'],['poison','ground','rock','ghost'],['steel']],[['fire','electric','poison','rock','steel'],['grass','bug'],['flying']],[['grass','fighting','bug'],['electric','rock','steel'],[]],[['fighting','poison'],['psychic','steel'],['dark']],[['grass','psychic','dark'],['fire','fighting','poison','flying','ghost','steel','fairy'],[]],[['fire','ice','flying','bug'],['fighting','ground','steel'],[]],[['psychic','ghost'],['dark'],['normal']],[['dragon'],['steel'],['fairy']],[['psychic','ghost'],['fighting','dark','fairy'],[]],[['ice','rock','fairy'],['fire','water','electric','steel'],[]],[['fighting','dragon','dark'],['fire','poison','steel'],[]]]
def find_type_advantage(n,m):
    if n == 'none':
        return ('no type advantage')
    if m in type_advantages[types.index(n)][0]:
        return ('super effective')
    elif m in type_advantages[types.index(n)][1]:
        return ('not very effective')
    elif m in type_advantages[types.index(n)][2]:
        return ('does not affect')
    else:
        return ('no type advantage')
#set board
o0 = 'out of Bounds'
o1 = 'out of Bounds'
o2 = 'out of Bounds'
o3 = 'out of Bounds'
o4 = 'out of Bounds'
o5 = 'out of Bounds'
o6 = 'out of Bounds'
o7 = 'out of Bounds'
o8 = 'out of Bounds'
o9 = 'out of Bounds'
a0 = 'out of Bounds'
a1 = 'wR1'
a2 = 'wP1'
a3 = '   '
a4 = '   '
a5 = '   '
a6 = '   '
a7 = 'bP1'
a8 = 'bR1'
a9 = 'out of Bounds'
b0 = 'out of Bounds'
b1 = 'wN1'
b2 = 'wP2'
b3 = '   '
b4 = '   '
b5 = '   '
b6 = '   '
b7 = 'bP2'
b8 = 'bN1'
b9 = 'out of Bounds'
c0 = 'out of Bounds'
c1 = 'wB1'
c2 = 'wP3'
c3 = '   '
c4 = '   '
c5 = '   '
c6 = '   '
c7 = 'bP3'
c8 = 'bB1'
c9 = 'out of Bounds'
d0 = 'out of Bounds'
d1 = 'wQ '
d2 = 'wP4'
d3 = '   '
d4 = '   '
d5 = '   '
d6 = '   '
d7 = 'bP4'
d8 = 'bQ '
d9 = 'out of Bounds'
e0 = 'out of Bounds'
e1 = 'wK '
e2 = 'wP5'
e3 = '   '
e4 = '   '
e5 = '   '
e6 = '   '
e7 = 'bP5'
e8 = 'bK '
e9 = 'out of Bounds'
f0 = 'out of Bounds'
f1 = 'wB2'
f2 = 'wP6'
f3 = '   '
f4 = '   '
f5 = '   '
f6 = '   '
f7 = 'bP6'
f8 = 'bB2'
f9 = 'out of Bounds'
g0 = 'out of Bounds'
g1 = 'wN2'
g2 = 'wP7'
g3 = '   '
g4 = '   '
g5 = '   '
g6 = '   '
g7 = 'bP7'
g8 = 'bN2'
g9 = 'out of Bounds'
h0 = 'out of Bounds'
h1 = 'wR2'
h2 = 'wP8'
h3 = '   '
h4 = '   '
h5 = '   '
h6 = '   '
h7 = 'bP8'
h8 = 'bR2'
h9 = 'out of Bounds'
j0 = 'out of Bounds'
j1 = 'out of Bounds'
j2 = 'out of Bounds'
j3 = 'out of Bounds'
j4 = 'out of Bounds'
j5 = 'out of Bounds'
j6 = 'out of Bounds'
j7 = 'out of Bounds'
j8 = 'out of Bounds'
j9 = 'out of Bounds'
filelist = ['o','a','b','c','d','e','f','g','h','j']
chessboard = [[o0,o1,o2,o3,o4,o5,o6,o7,o8,o9],[a0,a1,a2,a3,a4,a5,a6,a7,a8,a9],[b0,b1,b2,b3,b4,b5,b6,b7,b8,b9],[c0,c1,c2,c3,c4,c5,c6,c7,c8,c9],[d0,d1,d2,d3,d4,d5,d6,d7,d8,d9],[e0,e1,e2,e3,e4,e5,e6,e7,e8,e9],[f0,f1,f2,f3,f4,f5,f6,f7,f8,f9],[g0,g1,g2,g3,g4,g5,g6,g7,g8,g9],[h0,h1,h2,h3,h4,h5,h6,h7,h8,h9],[j0,j1,j2,j3,j4,j5,j6,j7,j8,j9]]
ref_chessboard = [['o0','o1','o2','o3','o4','o5','o6','o7','o8','o9'],['a0','a1','a2','a3','a4','a5','a6','a7','a8','a9'],['b0','b1','b2','b3','b4','b5','b6','b7','b8','b9'],['c0','c1','c2','c3','c4','c5','c6','c7','c8','c9'],['d0','d1','d2','d3','d4','d5','d6','d7','d8','d9'],['e0','e1','e2','e3','e4','e5','e6','e7','e8','e9'],['f0','f1','f2','f3','f4','f5','f6','f7','f8','f9'],['g0','g1','g2','g3','g4','g5','g6','g7','g8','g9'],['h0','h1','h2','h3','h4','h5','h6','h7','h8','h9'],['j0','j1','j2','j3','j4','j5','j6','j7','j8','j9']]
move_history = []
#set pieces
#sample_piece = [type,fileno,rank,position,[list of posible moves]]
bP1 = ['p',1,7,'a7']
bP2 = ['p',2,7,'b7']
bP3 = ['p',3,7,'c7']
bP4 = ['p',4,7,'d7']
bP5 = ['p',5,7,'e7']
bP6 = ['p',6,7,'f7']
bP7 = ['p',7,7,'g7']
bP8 = ['p',8,7,'h7']
bR1 = ['r',1,8,'a8']
bR2 = ['r',8,8,'h8']
bB1 = ['b',3,8,'c8']
bB2 = ['b',6,8,'f8']
bN1 = ['n',2,8,'b8']
bN2 = ['n',3,8,'g8']
bQ = ['q',4,8,'d8']
bK = ['k',5,8,'e8', 'none']
wP1 = ['p',1,2,'a2']
wP2 = ['p',2,2,'b2']
wP3 = ['p',3,2,'c2']
wP4 = ['p',4,2,'d2']
wP5 = ['p',5,2,'e2']
wP6 = ['p',6,2,'f2']
wP7 = ['p',7,2,'g2']
wP8 = ['p',8,2,'h2']
wR1 = ['r',1,1,'a1']
wR2 = ['r',8,1,'h1']
wB1 = ['b',3,1,'c1']
wB2 = ['b',6,1,'f1']
wN1 = ['n',2,1,'b1']
wN2 = ['n',7,1,'g1']
wQ = ['q',4,1,'d1']
wK = ['k',5,1,'e1','none']
blackpieces = [bP1,bP2,bP3,bP4,bP5,bP6,bP7,bP8,bR1,bR2,bB1,bB2,bN1,bN2,bQ,bK]
black_ref_list = ['bP1','bP2','bP3','bP4','bP5','bP6','bP7','bP8','bR1','bR2','bB1','bB2','bN1','bN2','bQ','bK']
whitepieces = [wP1,wP2,wP3,wP4,wP5,wP6,wP7,wP8,wR1,wR2,wB1,wB2,wN1,wN2,wQ,wK]
white_ref_list = ['wP1','wP2','wP3','wP4','wP5','wP6','wP7','wP8','wR1','wR2','wB1','wB2','wN1','wN2','wQ','wK']
allpieces = [wP1,wP2,wP3,wP4,wP5,wP6,wP7,wP8,wR1,wR2,wB1,wB2,wN1,wN2,wQ,bP1,bP2,bP3,bP4,bP5,bP6,bP7,bP8,bR1,bR2,bB1,bB2,bN1,bN2,bQ]
allreflist = ['wP1','wP2','wP3','wP4','wP5','wP6','wP7','wP8','wR1','wR2','wB1','wB2','wN1','wN2','wQ','bP1','bP2','bP3','bP4','bP5','bP6','bP7','bP8','bR1','bR2','bB1','bB2','bN1','bN2','bQ']
for i in whitepieces:
    i.append(types[randint(0,17)])
for i in blackpieces:
    i.append(types[randint(0,17)])
wK.pop(-1)
bK.pop(-1)
def check_types(allpieces,allreflist):
    for i in range(len(allreflist)):
        print(str(i+1) + '. ' + allreflist[i] + ' - ' + (allpieces[i])[-1])
def check_type_advantages():
    for i in types:
        for j in types:
            print(i,'-',j)
            find_type_advantage(i,j)
            print('\n')

def check_board(chessboard):
    print('    | 1 | 2 | 3 | 4 | 5 | 6 | 7 | 8 |')
    print('-------------------------------------')
    for i in chessboard[1:-1]:
        print('| ' + filelist[chessboard.index(i)] + ' ', end = '|')
        for j in i[1:-1]:
            print(j,end = '|')
        print('\n-------------------------------------')

def opp(n):
    if n in whitepieces:
        return 'b'
    else:
        return 'w'

def my(n):
    if n in blackpieces:
        return 'b'
    else:
        return 'w'


def generate_pawn_move(n):
    moves = []
    if n in whitepieces:
        if chessboard[n[1]][n[2]+1] == '   ':
            moves.append(ref_chessboard[n[1]][n[2]+1])
            if n[2] == 2 and chessboard[n[1]][n[2]+2] == '   ':
                moves.append(ref_chessboard[n[1]][n[2]+2])
        if 'b' in chessboard[n[1]-1][n[2]+1]:
            moves.append(filelist[n[1]] + 'x' + ref_chessboard[n[1]-1][n[2]+1])
        if 'b' in chessboard[n[1]+1][n[2]+1]:
            moves.append(filelist[n[1]] + 'x' + ref_chessboard[n[1]+1][n[2]+1])
    elif n in blackpieces:
        if chessboard[n[1]][n[2]-1] == '   ':
            moves.append(ref_chessboard[n[1]][n[2]-1])
            if n[2] == 7 and chessboard[n[1]][n[2]-2] == '   ':
                moves.append(ref_chessboard[n[1]][n[2]-2])
        if 'w' in chessboard[n[1]-1][n[2]-1]:
            moves.append(filelist[n[1]] + 'x' + ref_chessboard[n[1]-1][n[2]-1])
        if 'w' in chessboard[n[1]+1][n[2]-1]:
            moves.append(filelist[n[1]] + 'x' + ref_chessboard[n[1]+1][n[2]-1])

    return moves
def generate_knight_move(n):
    moves = []
    files = [-2,-2,-1,-1,1,1,2,2]
    ranks = [-1,1,-2,2,-2,2,-1,1]
    if n[1] == 1:
        while -2 in files:
            ranks.pop(files.index(-2))
            files.pop(files.index(-2))
    elif n[1] == 8:
        while 2 in files:
            ranks.pop(files.index(2))
            files.pop(files.index(2))
    if n[2] == 1:
        while -2 in ranks:
            files.pop(ranks.index(-2))
            ranks.pop(ranks.index(-2))
    elif n[2] == 8:
        while 2 in ranks:
            files.pop(ranks.index(2))
            ranks.pop(ranks.index(2))
    for i in range(len(files)):
        if chessboard[n[1]+files[i]][n[2]+ranks[i]] == '   ':
            moves.append('N' + ref_chessboard[n[1]+files[i]][n[2]+ranks[i]])
        elif opp(n) in chessboard[n[1]+files[i]][n[2]+ranks[i]]:
            moves.append('Nx' + ref_chessboard[n[1]+files[i]][n[2]+ranks[i]])

    return moves
def generate_rook_move(n):
    moves = []
    filee = n[1]
    rank = n[2]
    while True:
        rank += 1
        if chessboard[filee][rank] == 'out of Bounds' or my(n) in chessboard[filee][rank]:
            break
        elif chessboard[filee][rank] == '   ':
            moves.append('R' + ref_chessboard[filee][rank])
        elif opp(n) in chessboard[filee][rank]:
            moves.append('Rx' + ref_chessboard[filee][rank])
            break
    filee = n[1]
    rank = n[2]
    while True:
        filee += 1
        if chessboard[filee][rank] == 'out of Bounds' or my(n) in chessboard[filee][rank]:
            break
        elif chessboard[filee][rank] == '   ':
            moves.append('R' + ref_chessboard[filee][rank])
        elif opp(n) in chessboard[filee][rank]:
            moves.append('Rx' + ref_chessboard[filee][rank])
            break
    filee = n[1]
    rank = n[2]
    while True:
        rank -= 1
        if chessboard[filee][rank] == 'out of Bounds' or my(n) in chessboard[filee][rank]:
            break
        elif chessboard[filee][rank] == '   ':
            moves.append('R' + ref_chessboard[filee][rank])
        elif opp(n) in chessboard[filee][rank]:
            moves.append('Rx' + ref_chessboard[filee][rank])
            break
    filee = n[1]
    rank = n[2]
    while True:
        filee -= 1
        if chessboard[filee][rank] == 'out of Bounds' or my(n) in chessboard[filee][rank]:
            break
        elif chessboard[filee][rank] == '   ':
            moves.append('R' + ref_chessboard[filee][rank])
        elif opp(n) in chessboard[filee][rank]:
            moves.append('Rx' + ref_chessboard[filee][rank])
            break
    return moves

def generate_bishop_move(n):
    moves = []
    filee = n[1]
    rank = n[2]
    while True:
        rank += 1
        filee += 1
        if chessboard[filee][rank] == 'out of Bounds' or my(n) in chessboard[filee][rank]:
            break
        elif chessboard[filee][rank] == '   ':
            moves.append('B' + ref_chessboard[filee][rank])
        elif opp(n) in chessboard[filee][rank]:
            moves.append('Bx' + ref_chessboard[filee][rank])
            break
    filee = n[1]
    rank = n[2]
    while True:
        rank -= 1
        filee += 1
        if chessboard[filee][rank] == 'out of Bounds' or my(n) in chessboard[filee][rank]:
            break
        elif chessboard[filee][rank] == '   ':
            moves.append('B' + ref_chessboard[filee][rank])
        elif opp(n) in chessboard[filee][rank]:
            moves.append('Bx' + ref_chessboard[filee][rank])
            break
    filee = n[1]
    rank = n[2]
    while True:
        rank -= 1
        filee -= 1
        if chessboard[filee][rank] == 'out of Bounds' or my(n) in chessboard[filee][rank]:
            break
        elif chessboard[filee][rank] == '   ':
            moves.append('B' + ref_chessboard[filee][rank])
        elif opp(n) in chessboard[filee][rank]:
            moves.append('Bx' + ref_chessboard[filee][rank])
            break
    filee = n[1]
    rank = n[2]
    while True:
        rank += 1
        filee -= 1
        if chessboard[filee][rank] == 'out of Bounds' or my(n) in chessboard[filee][rank]:
            break
        elif chessboard[filee][rank] == '   ':
            moves.append('B' + ref_chessboard[filee][rank])
        elif opp(n) in chessboard[filee][rank]:
            moves.append('Bx' + ref_chessboard[filee][rank])
            break

    return moves
def generate_queen_move(n):
    moves = generate_rook_move(n) + generate_bishop_move(n)
    movesfinal = []
    for i in moves:
        movesfinal.append('Q' + i[1:])
    return movesfinal
def generate_king_move(n):
    moves = []
    ranks = [1,1,0,-1,-1,-1,0,1]
    files = [0,1,1,1,0,-1,-1,-1]
    for i in range(len(files)):
        if chessboard[n[1] + files[i]][n[2] + ranks[i]] == '   ':
            moves.append('K' + ref_chessboard[n[1] + files[i]][n[2] + ranks[i]])
    return moves
def generate_move(n):
    if n[0] == 'p':
        return generate_pawn_move(n)
    if n[0] == 'r':
        return generate_rook_move(n)
    if n[0] == 'n':
        return generate_knight_move(n)
    if n[0] == 'b':
        return generate_bishop_move(n)
    if n[0] == 'q':
        return generate_queen_move(n)
    if n[0] == 'k':
        return generate_king_move(n)


def generate_all(n):
    all = []
    original = []
    for i in n:
        move = generate_move(i)
        if move:
            for j in move:
                all.append(j)
                original.append(i)
    return [all,original]
def turn(n,chessboard,move_history,whitepieces,blackpieces):
    choice = ''
    movelist = generate_all(n)
    all = movelist[0]
    original = movelist[1]
    count = 0
    print('    | 1 | 2 | 3 | 4 | 5 | 6 | 7 | 8 |')
    print('-------------------------------------', )
    for i in chessboard[1:-1]:
        print('| ' + filelist[chessboard.index(i)] + ' ', end = '|')
        for j in i[1:-1]:
            print(j,end = '|')
        print('     ' + (allreflist[count] + '-' + allpieces[count][-1] + (15 - len(allreflist[count] + '-' + allpieces[count][-1])) * ' '), (allreflist[count+15] + '-' + allpieces[count+15][-1] + (15 - len(allreflist[count+15] + '-' + allpieces[count+15][-1])) * ' '))
        count += 1
        print('-------------------------------------', end = '')
        print('     ' + (allreflist[count] + '-' + allpieces[count][-1] + (15 - len(allreflist[count] + '-' + allpieces[count][-1])) * ' '), (allreflist[count+15] + '-' + allpieces[count+15][-1] + (15 - len(allreflist[count+15] + '-' + allpieces[count+15][-1])) * ' ')) if count < 15 else print('')
        count += 1
    while not choice:
        x = input('Enter move: ')
        if x == 'resign':
            return 'resign'
        elif x == 'check types':
            check_types(allpieces,allreflist)
        elif x == 'check type advantage':
            check_type_advantages()
        elif x == 'chessboard':
            check_board(chessboard)
        elif x in all:
            choice = x
        else:
            print('invalid input')
    if 'x' in choice:
        if chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])] in white_ref_list:
            if find_type_advantage(original[all.index(choice)][-1],whitepieces[white_ref_list.index(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])])][-1]) == 'no type advantage':
                whitepieces.pop(white_ref_list.index(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])]))
                white_ref_list.remove(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])])
                chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])] = chessboard[original[all.index(choice)][1]][original[all.index(choice)][2]]
                chessboard[original[all.index(choice)][1]][original[all.index(choice)][2]] = '   '
                original[all.index(choice)][1] = filelist.index(choice[-2])
                original[all.index(choice)][2] = ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])
                move_history.append(choice)
            elif find_type_advantage(original[all.index(choice)][-1],whitepieces[white_ref_list.index(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])])][-1]) == 'does not affect':
                print('It is completely ineffective')
            elif find_type_advantage(original[all.index(choice)][-1],whitepieces[white_ref_list.index(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])])][-1]) == 'not very effective':
                print('It is not very effective')
                whitepieces.pop(white_ref_list.index(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])]))
                white_ref_list.remove(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])])
                black_ref_list.pop(blackpieces.index(original[all.index(choice)]))
                blackpieces.remove(original[all.index(choice)])
                chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])] = '   '
                chessboard[original[all.index(choice)][1]][original[all.index(choice)][2]] = '   '
            elif find_type_advantage(original[all.index(choice)][-1],whitepieces[white_ref_list.index(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])])][-1]) == 'super effective':
                whitepieces.pop(white_ref_list.index(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])]))
                white_ref_list.remove(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])])
                chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])] = chessboard[original[all.index(choice)][1]][original[all.index(choice)][2]]
                chessboard[original[all.index(choice)][1]][original[all.index(choice)][2]] = '   '
                original[all.index(choice)][1] = filelist.index(choice[-2])
                original[all.index(choice)][2] = ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])
                print('It is super effective\n\nBlack\'s Turn Again')
                change = turn(blackpieces,chessboard,move_history,whitepieces,blackpieces)
                chessboard = change[0]
                move_history = change[1]
                whitepieces = change[2]
                blackpieces = change[3]
        elif chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])] in black_ref_list:
            if find_type_advantage(original[all.index(choice)][-1],blackpieces[black_ref_list.index(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])])][-1]) == 'no type advantage':
                blackpieces.pop(black_ref_list.index(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])]))
                black_ref_list.remove(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])])
                chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])] = chessboard[original[all.index(choice)][1]][original[all.index(choice)][2]]
                chessboard[original[all.index(choice)][1]][original[all.index(choice)][2]] = '   '
                original[all.index(choice)][1] = filelist.index(choice[-2])
                original[all.index(choice)][2] = ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])
                move_history.append(choice)
            elif find_type_advantage(original[all.index(choice)][-1],blackpieces[black_ref_list.index(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])])][-1]) == 'does not affect':
                print('It is completely ineffective')
            elif find_type_advantage(original[all.index(choice)][-1],blackpieces[black_ref_list.index(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])])][-1]) == 'not very effective':
                print('It not very effective')
                blackpieces.pop(black_ref_list.index(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])]))
                black_ref_list.remove(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])])
                white_ref_list.pop(whitepieces.index(original[all.index(choice)]))
                whitepieces.remove(original[all.index(choice)])
                chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])] = '   '
                chessboard[original[all.index(choice)][1]][original[all.index(choice)][2]] = '   '
            elif find_type_advantage(original[all.index(choice)][-1],blackpieces[black_ref_list.index(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])])][-1]) == 'super effective':
                blackpieces.pop(black_ref_list.index(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])]))
                black_ref_list.remove(chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])])
                chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])] = chessboard[original[all.index(choice)][1]][original[all.index(choice)][2]]
                chessboard[original[all.index(choice)][1]][original[all.index(choice)][2]] = '   '
                original[all.index(choice)][1] = filelist.index(choice[-2])
                original[all.index(choice)][2] = ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])
                print('It is super effective\n\nWhite\'s Turn Again')
                change = turn(whitepieces,chessboard,move_history,whitepieces,blackpieces)
                chessboard = change[0]
                move_history = change[1]
                whitepieces = change[2]
                blackpieces = change[3]
    else:
        chessboard[filelist.index(choice[-2])][ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])] = chessboard[original[all.index(choice)][1]][original[all.index(choice)][2]]
        chessboard[original[all.index(choice)][1]][original[all.index(choice)][2]] = '   '
        original[all.index(choice)][1] = filelist.index(choice[-2])
        original[all.index(choice)][2] = ref_chessboard[filelist.index(choice[-2])].index(choice[-2:])
        move_history.append(choice)
    return [chessboard,move_history,whitepieces,blackpieces]
print('Rules:\n\nThe game is played by inputing standard algebraic chess notetation\nPieces move the same as in regular chess but without check\nThe objective is to capture the opponent king\n\nThere are special effects upon capturing based on the type of the pieces\nWhen super effective the player can move once more\nWhen not very effective both the captured piece and the capturing piece is catured\nWhen completely not effective the move does not do anything\n\nTo check type advantages enter "check type advantage"\nTo check the type for each piece enter "check type"\nTo check the chessboard enter "chessboard"\n\nEn passant and Castling is not allowed\n')

while wK in whitepieces and bK in blackpieces:
    MOVE = 'white'
    print('\nWhite\'s Move')
    change = turn(whitepieces,chessboard,move_history,whitepieces,blackpieces)
    if change == 'resign':
        break
    chessboard = change[0]
    move_history = change[1]
    whitepieces = change[2]
    blackpieces = change[3]
    MOVE = 'black'
    print('\nBlack\'s Move')
    change = turn(blackpieces,chessboard,move_history,whitepieces,blackpieces)
    if change == 'resign':
        break
    chessboard = change[0]
    move_history = change[1]
    whitepieces = change[2]
    blackpieces = change[3]
if MOVE == 'white':
    print('White Wins!')
else:
    print('Black Wins!')
